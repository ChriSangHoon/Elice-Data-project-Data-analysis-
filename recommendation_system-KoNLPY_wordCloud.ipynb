# %%
# !pip install konlpy

# %%
import warnings
warnings.simplefilter("ignore")

import konlpy
konlpy.__version__

import pandas as pd

# %%
movies = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/project-dancingMachine/film_festival_final.csv')
movies.head(2)

# %%
X = movies['title'] + " " + movies['plot']
X

# %%
type(X)

# %%
c = pd.Series.to_string(X)
c

# %% [markdown]
# ## 형태소 분석
# KoNLPy 라이브러리
#
# ### Hannanum: 한나눔.
# KAIST Semantic Web Research Center 개발.
#
# http://semanticweb.kaist.ac.kr/hannanum/

# %%
from konlpy.tag import *

hannanum = Hannanum()

# %%
hannanum.nouns(c[:40])

# %%
keyword = hannanum.nouns(c)

# %%
text = " ".join(keyword)
text

# %%
kkma.nouns(c[:40])

# %% [markdown]
# ## 형태소 추출
# 명사 뿐 아니라 모든 품사의 형태소를 알아내려면 morphs라는 명령을 사용한다.

# %%
hannanum.morphs(c[:40])

# %% [markdown]
# ## 품사 부착
# pos 명령을 사용.
#
# 한국어 품사 태그 세트: 21세기 세종계획 품사 태그세트
# - 형태소 분석기마다 사용하는 품사 태그가 다르다.
# - 각 형태소 분석기에 대한 문서를 참조해야 한다.

# %%
hannanum.pos(c[:40])

# %%
import pandas as pd

# %%
# %matplotlib inline  

import matplotlib as mpl 
import matplotlib.pyplot as plt 
import matplotlib.font_manager as fm  

# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

path = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf' 
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)

fm._rebuild()
mpl.rcParams['axes.unicode_minus'] = False

# %%
pip install wordcloud

# %%
import numpy as np
from wordcloud import WordCloud

wordcloud = WordCloud(
    font_path='/content/drive/MyDrive/Colab Notebooks/project-dancingMachine/NANUMSQUAREROUNDB.TTF',
    width = 800,
    height = 800,
)

keyword = wordcloud.generate(text)
array = keyword.to_array()

plt.figure(figsize=(30,30))
plt.imshow(
    array,
    interpolation="bilinear"
    )
plt.axis("off")
plt.show
