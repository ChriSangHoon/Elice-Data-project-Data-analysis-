# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
#
# ...

# %%
# ======================================(0): pandas 시작
import pandas as pd
print(pd.__version__)
# Out:
# 1.3.5

# %%
# ======================================(1): 파일 불러오기 (ALL)
df00 = pd.read_csv('./film_festival_2000.csv', encoding='cp949') # 인코딩 해와야 함 룰루~
df01 = pd.read_csv('./film_festival_2001.csv', encoding='cp949')
df02 = pd.read_csv('./film_festival_2002.csv', encoding='cp949')
df03 = pd.read_csv('./film_festival_2003.csv', encoding='cp949')
df04 = pd.read_csv('./film_festival_2004.csv', encoding='cp949')
df05 = pd.read_csv('./film_festival_2005.csv', encoding='cp949')
df06 = pd.read_csv('./film_festival_2006.csv', encoding='cp949')
df07 = pd.read_csv('./film_festival_2007.csv', encoding='cp949')
df08 = pd.read_csv('./film_festival_2008.csv', encoding='cp949')
df09 = pd.read_csv('./film_festival_2009.csv', encoding='cp949')
df10 = pd.read_csv('./film_festival_2010.csv', encoding='cp949')
df11 = pd.read_csv('./film_festival_2011.csv', encoding='cp949')
df12 = pd.read_csv('./film_festival_2012.csv', encoding='cp949')
df13 = pd.read_csv('./film_festival_2013.csv', encoding='cp949')
df14 = pd.read_csv('./film_festival_2014.csv', encoding='cp949')
df15 = pd.read_csv('./film_festival_2015.csv', encoding='cp949')
df16 = pd.read_csv('./film_festival_2016.csv', encoding='cp949')
df17 = pd.read_csv('./film_festival_2017.csv', encoding='cp949')
df18 = pd.read_csv('./film_festival_2018.csv', encoding='cp949')
df19 = pd.read_csv('./film_festival_2019.csv', encoding='cp949')
df20 = pd.read_csv('./film_festival_2020.csv', encoding='cp949')
df21 = pd.read_csv('./film_festival_2021.csv', encoding='cp949')

# %% [markdown]
# * 그냥 끄적인 데이터 상태 확인하는 과정 (Series 데이터)

# %% [markdown]
# ## DB1 에서 중복값 제거
# - `출품작` && `감독`

# %%
# ======================================(2): 중복 제거 `for문` 쓰면 되는 데 ㅎ_ㅎ 빠르게 하고 설계 해보기
db2_raw_00 = df00.drop_duplicates(['출품작', '감독'], ignore_index=True) # 인덱스 새로 설정
db2_raw_01 = df01.drop_duplicates(['출품작', '감독'], ignore_index=True)
db2_raw_02 = df02.drop_duplicates(['출품작', '감독'], ignore_index=True)
db2_raw_03 = df03.drop_duplicates(['출품작', '감독'], ignore_index=True)
db2_raw_04 = df04.drop_duplicates(['출품작', '감독'], ignore_index=True)
db2_raw_05 = df05.drop_duplicates(['출품작', '감독'], ignore_index=True)
db2_raw_06 = df06.drop_duplicates(['출품작', '감독'], ignore_index=True)
db2_raw_07 = df07.drop_duplicates(['출품작', '감독'], ignore_index=True)
db2_raw_08 = df08.drop_duplicates(['출품작', '감독'], ignore_index=True)
db2_raw_09 = df09.drop_duplicates(['출품작', '감독'], ignore_index=True)
db2_raw_10 = df10.drop_duplicates(['출품작', '감독'], ignore_index=True)
db2_raw_11 = df11.drop_duplicates(['출품작', '감독'], ignore_index=True)
db2_raw_12 = df12.drop_duplicates(['출품작', '감독'], ignore_index=True)
db2_raw_13 = df13.drop_duplicates(['출품작', '감독'], ignore_index=True)
db2_raw_14 = df14.drop_duplicates(['출품작', '감독'], ignore_index=True)
db2_raw_15 = df15.drop_duplicates(['출품작', '감독'], ignore_index=True)
db2_raw_16 = df16.drop_duplicates(['출품작', '감독'], ignore_index=True)
db2_raw_17 = df17.drop_duplicates(['출품작', '감독'], ignore_index=True)
db2_raw_18 = df18.drop_duplicates(['출품작', '감독'], ignore_index=True)
db2_raw_19 = df19.drop_duplicates(['출품작', '감독'], ignore_index=True)
db2_raw_20 = df20.drop_duplicates(['출품작', '감독'], ignore_index=True)
db2_raw_21 = df21.drop_duplicates(['출품작', '감독'], ignore_index=True)
db2_raw_00
# Out:
#        연도                  영화제      장르            출품작   감독  \
# 0    2000             타이베이 영화제  일반(종합)            물안경  이수연
# 1    2000             타이베이 영화제  일반(종합)          자반고등어  김용화
# 2    2000             타이베이 영화제  일반(종합)          오! 수정  홍상수
# 3    2000             타이베이 영화제  일반(종합)              섬  김기덕
# 4    2000             타이베이 영화제  일반(종합)             가위  이기철
# ..    ...                  ...     ...            ...  ...
# 107  2000  판타스포르토 - 오포르토 국제영화제     판타지           닥터 K  곽경택
# 108  2000        유바리 국제판타스틱영화제     판타지  건축무한 육면각체의 비밀  유상욱
# 109  2000            베를린 국제영화제  일반(종합)     노래로 태양을 쏘다  조재홍
# 110  2000            베를린 국제영화제  일반(종합)         고추 말리기  장희선
# 111  2000           부산영화평론가협회상  일반(종합)           진실게임  김기영
#
#                        출품분야   수상내역  수상인
# 0    Focus on Korean CInema    NaN  NaN
# 1    Focus on Korean CInema    NaN  NaN
# 2    Focus on Korean CInema    NaN  NaN
# 3    Focus on Korean CInema    NaN  NaN
# 4    Focus on Korean CInema    NaN  NaN
# ...

# %% [markdown]
# ## null 값 처리
# - 개수 확인
# -

# %%
# ======================================(3): null 값 개수 확인
from pandas import Series, DataFrame

count_NaN = {'cnt_NaN':[db2_raw_00['감독'].isnull().sum(),
                    db2_raw_01['감독'].isnull().sum(),
                    db2_raw_02['감독'].isnull().sum(),
                    db2_raw_03['감독'].isnull().sum(),
                    db2_raw_04['감독'].isnull().sum(),
                    db2_raw_05['감독'].isnull().sum(),
                    db2_raw_06['감독'].isnull().sum(),
                    db2_raw_07['감독'].isnull().sum(),
                    db2_raw_08['감독'].isnull().sum(),
                    db2_raw_09['감독'].isnull().sum(),
                    db2_raw_10['감독'].isnull().sum(),
                    db2_raw_11['감독'].isnull().sum(),
                    db2_raw_12['감독'].isnull().sum(),
                    db2_raw_13['감독'].isnull().sum(),
                    db2_raw_14['감독'].isnull().sum(),
                    db2_raw_15['감독'].isnull().sum(),
                    db2_raw_16['감독'].isnull().sum(),
                    db2_raw_17['감독'].isnull().sum(),
                    db2_raw_18['감독'].isnull().sum(),
                    db2_raw_19['감독'].isnull().sum(),
                    db2_raw_20['감독'].isnull().sum(),
                    db2_raw_21['감독'].isnull().sum(),]}
cnt_NaN = DataFrame(count_NaN)
cnt_NaN
# Out:
#     cnt_NaN
# 0         3
# 1         1
# 2         3
# 3         1
# 4         2
# 5         1
# 6         7
# 7        17
# 8         5
# 9         9
# 10        6
# 11       22
# 12       25
# 13       79
# 14       31
# 15        7
# 16       16
# 17       28
# 18       34
# 19       16
# 20      447
# 21       95

# %%
cnt_NaN.describe()
# Out:
#           cnt_NaN
# count   22.000000
# mean    38.863636
# std     94.345513
# min      1.000000
# 25%      3.500000
# 50%     12.500000
# 75%     27.250000
# max    447.000000

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7,6))
boxplot = cnt_NaN.boxplot(column=['cnt_NaN'])

# %%
cnt_NaN.to_csv("count_NaN-all.csv", index=True, header=True)

# %% [markdown]
# ## 필요한 열(Columns) 추출
# - index , '출품작', '감독'

# %%
# ======================================(4-1): 의미있는 col 만 추출 ***** START
db2 = db2_raw_21[['출품작', '감독']]
# db2

# %% [markdown]
# ## 감독 column NaN 값이면 제거
# - NaN 처리 방법 고민 전에 우선 BE 에 넘겨야 해서 관련 행 제거하고 진행

# %%
# ======================================(4-2): NaN(결측값) 행 제거
db2_nan = db2.dropna(axis=0)
# db2_nan

# %%
# ======================================(): column 명 영문 변경
db2_nan.columns = ['title', 'director']
db2_nan
# Out:
#              title director
# 0     뉴타운 생존자 수색작전      강민구
# 1             모가디슈      류승완
# 3         쓸모 없는 녀석      김중회
# 4             낮과 달      이영아
# 5           섬이없는지도      김성은
# ..             ...      ...
# 638        조의(JOY)      권용재
# 639            이발소      임윤기
# 641  추운겨울에도 빛이 있다.      최정한
# 642   죽고 싶은 날에 한하여      김묘욱
# 643         스마일 클럽      최은우
#
# [549 rows x 2 columns]

# %%
# ======================================(5-2): csv 로 저장
db2_nan.to_csv("db2_title_NaN_2021.csv", index=True, header=True)
